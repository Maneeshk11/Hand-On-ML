# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %% [markdown]
# ### (1)

# %% [markdown]
# #### a)
#  The shape of the level curves at T (x, y) = $100 / (x^2 + y^2 + 1)$ is a "Circle". The equation represents a circle on a 2D plane and all the points are eqidistant from the center.
#
# #### b)
# The hottest point on the plane is at the center (0, 0). This is because temperature is inverely proportional to the square of distance from center in this particular equation.
#
# Hottest point = (0, 0)

# %%
def calcTemp(x, y):
    return 100/(x**2 + y**2 + 1)

# %%
hottest_temperature = calcTemp(0, 0)
hottest_temperature
# Out:
# 100.0

# %% [markdown]
# Hottest point is calculated to be 100 degrees at (0, 0)

# %% [markdown]
# #### c)

# %% [markdown]
# To find the direction of increase or decrease, we first calculate the gradient. The gradient of the function is:
# ΔT = [ $-200x/(x^2 + y^2 + 1)^2$, $-200y/(x^2 + y^2 + 1)^2$ ]

# %%
def calculateGradient(x, y):
    return (-200*x / (x**2 + y**2 + 1)**2, -200*y / (x**2 + y**2 + 1)**2)

# %%
greatest_increase = calculateGradient(3, 2)
greatest_increase
# Out:
# (-3.061224489795918, -2.0408163265306123)

# %% [markdown]
# The greatest increase is in directio nof (-3.06, -2.04)

# %%
def calculateMagnitude(x, y):
    return math.sqrt(x**2 + y**2)

# %%
greatest_increase_mag = calculateMagnitude(greatest_increase[0], greatest_increase[1])
greatest_increase_mag
# Out:
# 3.6791339545550907

# %% [markdown]
# The greatest increase magnitude is calculated to be 3.67

# %% [markdown]
# #### d)

# %% [markdown]
# The direction of greatest decrease is opposite the greatest increase so it is (3.06, 2.4)

# %%
-1*calculateGradient(3, 2)[0], -1* calculateGradient(3, 2)[1]
# Out:
# (3.061224489795918, 2.0408163265306123)

# %% [markdown]
# #### e)

# %% [markdown]
# A direction at (3, 2) where there is no temperature change should be normal to the gradient direction (dot product should be 0)
#
# Gradient = (-3.06, -2.04)
# So a vector could be `(2.04, -3.06)`

# %% [markdown]
# ### (2)

# %% [markdown]
# given equation : $ f(x, y) = 10x^2y - 5x^2 - 4y^2 - x^4 - 2y^4 $

# %% [markdown]
# #### a)

# %% [markdown]
# $$\frac{\partial f}{\partial x} = 20xy - 10x - 4x^3$$
# $$\frac{\partial f}{\partial y} = 10x^2 - 8y - 8y^3$$
#
# Simplifying and solving the 2 equations, we get 5 critical points at:
#
# (x, y) = (-2.644, 1.898)
#
# (x, y) = (-0.856, 0.646)
#
# (x, y) = (0, 0)
#
# (x, y) = (0.856, 0.646)
#
# (x, y) = (2.644, 1.898)

# %%
def func(x, y):
    return 10*x**2 * y - 5*x**2 - 4* y**2 - x**4 - 2*y**4

# %% [markdown]
# Corresponding function values for the critical points:

# %%
func(-2.644, 1.898)
# Out:
# 8.495854299872011

# %%
func(-0.856, 0.646)
# Out:
# -1.4846767734079995

# %%
func(0, 0)
# Out:
# 0

# %%
func(0.856, 0.646)
# Out:
# -1.4846767734079995

# %%
func(2.644, 1.898)
# Out:
# 8.495854299872011

# %% [markdown]
# $$\frac{\partial f}{\partial x^2} = 20y - 10 - 12x^2$$
# $$\frac{\partial^2 f}{\partial xy} = 20x$$
# $$\frac{\partial^2 f}{\partial y^2} = -8 - 24y^2$$
# $$\frac{\partial^2 f}{\partial yx} = 20x$$
#
# Using the above second derivative values and a hessian,
#
# (x, y) = (-2.644, 1.898) => Maximum
#
# (x, y) = (-0.856, 0.646) => Saddle point
#
# (x, y) = (0, 0) => Maximum
#
# (x, y) = (0.856, 0.646) => Saddle point
#
# (x, y) = (2.644, 1.898) => Maximum

# %% [markdown]
# #### b)

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-2.7, 2.7, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array([func(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)
ax.plot_surface(X, Y, Z)
ax.plot(-2.644, 1.898, func(-2.644, 1.898), marker='o', color='r', markersize="10")
ax.plot(0, 0, func(0, 0),  marker='o', color='r', markersize="10")
ax.plot(-0.856, 0.646, func(-2.644, 1.898),  marker='o', color='r', markersize="10")
ax.plot(0.856, 0.646, func(0.856, 0.646),  marker='o', color='r', markersize="10")
ax.plot(2.644, 1.898, func(2.644, 1.898),  marker='o', color='r', markersize="10")

plt.show()

# %% [markdown]
# contour plot

# %%
x = y = np.arange(-2.7, 2.7, 0.05)
X, Y = np.meshgrid(x, y)
critical_points = [(-2.644, 1.898), (0, 0), (-0.856, 0.646), (0.856, 0.646), (2.644, 1.898)]
critical_Z_values = [func(x, y) for x, y in critical_points]
critical_Z_values = critical_Z_values.sort()
fig, ax = plt.subplots(1, 1) 
Z = func(X, Y)
ax.contour(X, Y, Z, levels=critical_Z_values)
ax.plot(-2.644, 1.898, marker='o', color='r', markersize="10")
ax.plot(0, 0, marker='o', color='r', markersize="10")
ax.plot(-0.856, 0.646,  marker='o', color='r', markersize="10")
ax.plot(0.856, 0.646, marker='o', color='r', markersize="10")
ax.plot(2.644, 1.898, marker='o', color='r', markersize="10")
plt.show()

# %% [markdown]
# ### (3)

# %%
A = [[2, 1, 2, 6],
    [6, 4, 3, 5],
    [8, 1, 4, 9],
    [9, 8, 7, 8]]

# %%
determinent = 0
for j in range(4):
    determinent += (-1)**(1+j) * A[1][j] * np.linalg.det(np.delete(np.delete(A, 1, 0), j, 1))

# %%
determinent
# Out:
# 228.99999999999994

# %%
np.linalg.det(A)
# Out:
# 229.00000000000028

# %% [markdown]
# As we can see, performing laplace expansion over the i=1 row gave similar result compared to the determinant of the matrix A

# %% [markdown]
# ### (4)

# %%
A = [[2, -1, 0],
    [-1, 2, -1],
    [0, -1, 2]]

# %% [markdown]
# A - λI = 0

# %% [markdown]
# Solving this we get the characteristic equation as $-λ^3+6λ^2-10λ+4$
#
# This will give roots as $λ=2,\:λ=2+\sqrt{2},\:λ=2-\sqrt{2}$
#
# The roots itself are the eigen values for the matrix A
#
# For a matrix to be positive definite, all it's eigen values should be positive. In the case of matrix A, all the values are greater than 0, hence `matrix A is positive definite`

# %% [markdown]
# Condition number of A:

# %%
np.linalg.cond(A)
# Out:
# 5.8284271247461925

# %% [markdown]
# ### (5)

# %%
A = np.array([[6, 5, 3],
    [4, 1, 5],
    [6, 3, 6],
    [5, 3, 6],
    [6, 6, 3]])

# %% [markdown]
# #### a)  Singular values of A:

# %%
u, singular_vals, vh = np.linalg.svd(A)

# %%
singular_vals
# Out:
# array([17.92667464,  4.69961929,  0.74021274])

# %% [markdown]
# #### b)

# %%
A_transpose = A.transpose()

# %%
eigen_values, eigen_vectors = np.linalg.eig(A_transpose @ A)

# %%
eigen_values
# Out:
# array([321.36566366,   0.54791491,  22.08642144])

# %% [markdown]
# #### c)

# %% [markdown]
# Rank of a matrix is the number of non-zero singular values

# %% [markdown]
# Rank of A = 3

# %%
np.linalg.matrix_rank(A)
# Out:
# 3

# %% [markdown]
# #### d)

# %% [markdown]
# There exists a unique solution for the equation Ax = b as the matrix A has a full-rank.

# %% [markdown]
# #### e)

# %%
b = np.array([-1, 2, 0, 3, 1])

# %%
np.linalg.lstsq(A, b, rcond=None)
# Out:
# (array([-2.06119825,  1.37336076,  1.54641296]),
#  array([2.62766778]),
#  3,
#  array([17.92667464,  4.69961929,  0.74021274]))

# %% [markdown]
# The above resulting is the vector x that minimizes ||Ax - b||

# %% [markdown]
# ### (6)

# %% [markdown]
# -> Gradient of Dot Product : $(A^T B + B^T A)x$
#
#     we get this after considering dot product of Ax and Bx as $(Ax)^T(Bx)$ and then differentiating it w.r.t "x".
#
# -> Hessian: $A^T B + B^T A$
#
#     we get this after double differentiating $(Ax)^T(Bx)$ w.r.t. "x".
#
#
# To calculate for Matrices A, B and a variable x:

# %%
def gradient_dot_product(A, B, x):
    return (A.T @ B + B.T @ A) @ x

def hessian_dot_product(A, B):
    return A.T @ B + B.T @ A

# %% [markdown]
# ### (7)

# %%
x = pd.read_csv("X.csv")

# %%
y = pd.read_csv("y.csv")

# %%
X = x.to_numpy()
y = y.to_numpy()

# %%
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
X_b = np.c_[np.ones((len(X), 1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[4.03111343],
#        [3.01728673]])

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 4.03111343],
#        [10.06568688]])

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# Implementing the mini-batch gradient descent on the above linear regression

# %%
results = []

# %% [markdown]
# #### Batch size: 1

# %%
theta_path_mgd = []

m = len(X_b)

n_iterations = 50
minibatch_size = 1

np.random.seed(42)
theta = np.random.randn(2,1) 

t0, t1 = 200, 1000
def learning_schedule(t):
    return t0 / (t + t1)

t = 0
for epoch in range(n_iterations):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, minibatch_size):
        t += 1
        xi = X_b_shuffled[i:i+minibatch_size]
        yi = y_shuffled[i:i+minibatch_size]
        gradients = 2/minibatch_size * xi.T.dot(xi.dot(theta) - yi)
        eta = learning_schedule(t)
        theta = theta - eta * gradients
        theta_path_mgd.append(theta)
theta
# Out:
# array([[4.09567744],
#        [3.02036801]])

# %%
theta_path_mgd = np.array(theta_path_mgd)

# %%
plt.figure(figsize=(7,4))
plt.plot(theta_path_mgd[:, 0], theta_path_mgd[:, 1], "g-+", linewidth=2, label="Mini-batch")
plt.scatter(theta_path_mgd[:, 0], theta_path_mgd[:, 1])
plt.legend(loc="upper left", fontsize=12)
plt.xlabel(r"$\theta_0$", fontsize=20)
plt.ylabel(r"$\theta_1$   ", fontsize=20, rotation=0)
plt.axis([2.5, 4.5, 2.3, 3.9])
plt.show()

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta)
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# #### Batch size: 5

# %%
theta_path_mgd = []

n_iterations = 50
minibatch_size = 5

np.random.seed(42)
theta = np.random.randn(2,1) 

t0, t1 = 200, 1000
def learning_schedule(t):
    return t0 / (t + t1)

t = 0
for epoch in range(n_iterations):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, minibatch_size):
        t += 1
        xi = X_b_shuffled[i:i+minibatch_size]
        yi = y_shuffled[i:i+minibatch_size]
        gradients = 2/minibatch_size * xi.T.dot(xi.dot(theta) - yi)
        eta = learning_schedule(t)
        theta = theta - eta * gradients
        theta_path_mgd.append(theta)
theta
# Out:
# array([[4.091022  ],
#        [3.01998581]])

# %%
theta_path_mgd = np.array(theta_path_mgd)
plt.figure(figsize=(7,4))
plt.plot(theta_path_mgd[:, 0], theta_path_mgd[:, 1], "g-+", linewidth=2, label="Mini-batch")
plt.scatter(theta_path_mgd[:, 0], theta_path_mgd[:, 1])
plt.legend(loc="upper left", fontsize=12)
plt.xlabel(r"$\theta_0$", fontsize=20)
plt.ylabel(r"$\theta_1$   ", fontsize=20, rotation=0)
plt.axis([2.5, 4.5, 2.3, 3.9])
plt.show()

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta)
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# #### Batch size: 10

# %%
theta_path_mgd = []

n_iterations = 50
minibatch_size = 10

np.random.seed(42)
theta = np.random.randn(2,1) 

t0, t1 = 200, 1000
def learning_schedule(t):
    return t0 / (t + t1)

t = 0
for epoch in range(n_iterations):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, minibatch_size):
        t += 1
        xi = X_b_shuffled[i:i+minibatch_size]
        yi = y_shuffled[i:i+minibatch_size]
        gradients = 2/minibatch_size * xi.T.dot(xi.dot(theta) - yi)
        eta = learning_schedule(t)
        theta = theta - eta * gradients
        theta_path_mgd.append(theta)
theta
# Out:
# array([[4.08716938],
#        [3.048975  ]])

# %%
theta_path_mgd = np.array(theta_path_mgd)
plt.figure(figsize=(7,4))
plt.plot(theta_path_mgd[:, 0], theta_path_mgd[:, 1], "g-+", linewidth=2, label="Mini-batch")
plt.scatter(theta_path_mgd[:, 0], theta_path_mgd[:, 1])
plt.legend(loc="upper left", fontsize=12)
plt.xlabel(r"$\theta_0$", fontsize=20)
plt.ylabel(r"$\theta_1$   ", fontsize=20, rotation=0)
plt.axis([2.5, 4.5, 2.3, 3.9])
plt.show()

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta)
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()
